# %% [markdown]
# <a href="https://colab.research.google.com/github/Diwagarbk/DATA-VISUALISATION/blob/main/devassignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
df=pd.read_csv('devassignment.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,4,7,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#               date    year  month   usg_no usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0       05-01-2014  2014.0    5.0  14492.0     RDU     36.0    11032.0    CUN
# 1       06-01-2007  2007.0    6.0  13204.0     MCO     33.0    16085.0    YHZ
# 2       12-01-2005  2005.0   12.0  11433.0     DTW     43.0    10411.0    AUA
# 3       04-01-2003  2003.0    4.0  13487.0     MSP     63.0    16304.0    ZIH
# 4       12-01-2005  2005.0   12.0  12016.0     GUM      5.0    11138.0    CRK
# ...            ...     ...    ...      ...     ...      ...        ...    ...
# 368278         NaN     NaN    NaN      NaN     NaN      NaN        NaN    NaN
# 368279         NaN     NaN    NaN      NaN     NaN      NaN        NaN    NaN
# 368280         NaN     NaN    NaN      NaN     NaN      NaN        NaN    NaN
# 368281         NaN     NaN    NaN      NaN     NaN      NaN        NaN    NaN
# 368282         NaN     NaN    NaN      NaN     NaN      NaN        NaN    NaN
#
# ...

# %%
df.head()
# Out:
#          date    year  month   usg_no usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05-01-2014  2014.0    5.0  14492.0     RDU     36.0    11032.0    CUN
# 1  06-01-2007  2007.0    6.0  13204.0     MCO     33.0    16085.0    YHZ
# 2  12-01-2005  2005.0   12.0  11433.0     DTW     43.0    10411.0    AUA
# 3  04-01-2003  2003.0    4.0  13487.0     MSP     63.0    16304.0    ZIH
# 4  12-01-2005  2005.0   12.0  12016.0     GUM      5.0    11138.0    CRK
#
#    fg_wac  airline_id carrier  carrier_ground        type  scheduled  charter  \
# 0   148.0     19534.0      AM             0.0  Passengers        0.0    315.0
# 1   951.0     20364.0      C6             0.0  Passengers        0.0    683.0
# 2   277.0     20344.0      RD             1.0  Passengers        0.0   1010.0
# 3   148.0     20204.0      MG             1.0  Passengers        0.0    508.0
# 4   766.0     20312.0      TZ             1.0  Passengers        0.0     76.0
#
#     total
# 0   315.0
# 1   683.0
# 2  1010.0
# 3   508.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368283 entries, 0 to 368282
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            499 non-null    object
#  1   year            499 non-null    float64
#  2   month           499 non-null    float64
#  3   usg_no          499 non-null    float64
#  4   usg_apt         499 non-null    object
#  5   usg_wac         499 non-null    float64
#  6   fg_apt_id       499 non-null    float64
#  7   fg_apt          499 non-null    object
#  8   fg_wac          499 non-null    float64
#  9   airline_id      499 non-null    float64
#  10  carrier         491 non-null    object
#  11  carrier_ground  499 non-null    float64
#  12  type            499 non-null    object
#  13  scheduled       499 non-null    float64
#  14  charter         499 non-null    float64
#  15  total           499 non-null    float64
# dtypes: float64(11), object(5)
# ...

# %%
df.describe()
# Out:
#               year       month        usg_no     usg_wac     fg_apt_id  \
# count   499.000000  499.000000    499.000000  499.000000    499.000000
# mean   2005.372745    6.044088  13150.286573   41.450902  13470.741483
# std       2.866742    3.593566   5709.837034   24.260283   2040.256045
# min    2001.000000    1.000000  10140.000000    1.000000  10148.000000
# 25%    2003.000000    3.000000  11433.000000   23.000000  11294.500000
# 50%    2005.000000    6.000000  13204.000000   34.000000  13605.000000
# 75%    2008.000000    9.000000  14018.000000   63.000000  15174.000000
# max    2014.000000   12.000000  99999.000000   93.000000  16322.000000
#
#            fg_wac    airline_id  carrier_ground  scheduled       charter  \
# count  499.000000    499.000000      499.000000      499.0    499.000000
# mean   421.657315  20262.080160        0.677355        0.0    827.054108
# std    302.811565    381.691413        0.467957        0.0   1443.048388
# ...

# %%
df.shape
# Out:
# (368283, 16)

# %%
df.isnull()
# Out:
#          date   year  month  usg_no  usg_apt  usg_wac  fg_apt_id  fg_apt  \
# 0       False  False  False   False    False    False      False   False
# 1       False  False  False   False    False    False      False   False
# 2       False  False  False   False    False    False      False   False
# 3       False  False  False   False    False    False      False   False
# 4       False  False  False   False    False    False      False   False
# ...       ...    ...    ...     ...      ...      ...        ...     ...
# 368278   True   True   True    True     True     True       True    True
# 368279   True   True   True    True     True     True       True    True
# 368280   True   True   True    True     True     True       True    True
# 368281   True   True   True    True     True     True       True    True
# 368282   True   True   True    True     True     True       True    True
#
#         fg_wac  airline_id  carrier  carrier_ground   type  scheduled  \
# ...

# %%
plt.plot(df.charter)

# %%
plt.scatter(df.charter,df.total,color='red')
plt.show()

# %%
x=df.charter
y=df.total
z=df.year
plt.scatter(x,y)
plt.scatter(y,z)
plt.scatter(z,x)
plt.legend(["charter","total","year"],loc='upper right')
plt.show()

# %%
plt.hist(df['total'])
plt.show()

# %%
plt.hist(df['fg_apt_id'])
plt.show()

# %%
plt.plot(df.usg_wac,color='b') 
plt.plot(df.fg_wac,color='r')
plt.show()

# %%
plt.plot(df.fg_wac,marker='o',color='g')
plt.show()

# %%
plt.plot(df.usg_wac,marker='*',color='y')
plt.show()

# %%
plt.plot(df.month, linestyle = 'dotted')
plt.show()

# %%
x=df.charter
y=df.total
plt.scatter(x,y,color='violet')
plt.grid()
plt.show()

# %%
plt.fill_between(df.charter,df.total,color='yellow')
plt.show()
